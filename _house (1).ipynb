# %%
import numpy as np

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Arcite Student\Downloads\house-prices (2).csv")
df
# Out:
#      Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0       1  114300  1790         2          2       2    No         East
# 1       2  114200  2030         4          2       3    No         East
# 2       3  114800  1740         3          2       1    No         East
# 3       4   94700  1980         3          2       3    No         East
# 4       5  119800  2130         3          3       3    No         East
# ..    ...     ...   ...       ...        ...     ...   ...          ...
# 123   124  119700  1900         3          3       3   Yes         East
# 124   125  147900  2160         4          3       3   Yes         East
# 125   126  113500  2070         2          2       2    No        North
# 126   127  149900  2020         3          3       1    No         West
# 127   128  124600  2250         3          3       4    No        North
#
# [128 rows x 8 columns]

# %% [markdown]
# df.index

# %%
print(df)
# Out:
#      Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0       1  114300  1790         2          2       2    No         East
# 1       2  114200  2030         4          2       3    No         East
# 2       3  114800  1740         3          2       1    No         East
# 3       4   94700  1980         3          2       3    No         East
# 4       5  119800  2130         3          3       3    No         East
# ..    ...     ...   ...       ...        ...     ...   ...          ...
# 123   124  119700  1900         3          3       3   Yes         East
# 124   125  147900  2160         4          3       3   Yes         East
# 125   126  113500  2070         2          2       2    No        North
# 126   127  149900  2020         3          3       1    No         West
# 127   128  124600  2250         3          3       4    No        North
#
# [128 rows x 8 columns]

# %%
print(df.shape)
# Out:
# (128, 8)

# %% [markdown]
# show the number of column and rows

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=128, step=1)

# %% [markdown]
# row of index

# %%
df.dtypes
# Out:
# Home            int64
# Price           int64
# SqFt            int64
# Bedrooms        int64
# Bathrooms       int64
# Offers          int64
# Brick             str
# Neighborhood      str
# dtype: object

# %% [markdown]
# shows the data type of each column

# %%
df.info
# Out:
# <bound method DataFrame.info of      Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0       1  114300  1790         2          2       2    No         East
# 1       2  114200  2030         4          2       3    No         East
# 2       3  114800  1740         3          2       1    No         East
# 3       4   94700  1980         3          2       3    No         East
# 4       5  119800  2130         3          3       3    No         East
# ..    ...     ...   ...       ...        ...     ...   ...          ...
# 123   124  119700  1900         3          3       3   Yes         East
# 124   125  147900  2160         4          3       3   Yes         East
# 125   126  113500  2070         2          2       2    No        North
# 126   127  149900  2020         3          3       1    No         West
# 127   128  124600  2250         3          3       4    No        North
#
# [128 rows x 8 columns]>

# %% [markdown]
# complete basic nformation about the dataset

# %%
df.select_dtypes
# Out:
# <bound method DataFrame.select_dtypes of      Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0       1  114300  1790         2          2       2    No         East
# 1       2  114200  2030         4          2       3    No         East
# 2       3  114800  1740         3          2       1    No         East
# 3       4   94700  1980         3          2       3    No         East
# 4       5  119800  2130         3          3       3    No         East
# ..    ...     ...   ...       ...        ...     ...   ...          ...
# 123   124  119700  1900         3          3       3   Yes         East
# 124   125  147900  2160         4          3       3   Yes         East
# 125   126  113500  2070         2          2       2    No        North
# 126   127  149900  2020         3          3       1    No         West
# 127   128  124600  2250         3          3       4    No        North
#
# [128 rows x 8 columns]>

# %% [markdown]
# select the numeric coloum only

# %%
print(df.values)
# Out:
# [[1 114300 1790 ... 2 'No' 'East']
#  [2 114200 2030 ... 3 'No' 'East']
#  [3 114800 1740 ... 1 'No' 'East']
#  ...
#  [126 113500 2070 ... 2 'No' 'North']
#  [127 149900 2020 ... 1 'No' 'West']
#  [128 124600 2250 ... 4 'No' 'North']]

# %% [markdown]
# display all value in the dataframe as in array

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=128, step=1),
#  Index(['Home', 'Price', 'SqFt', 'Bedrooms', 'Bathrooms', 'Offers', 'Brick',
#         'Neighborhood'],
#        dtype='str')]

# %% [markdown]
# show row index and coloum

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# number of dimension

# %%
df.size
# Out:
# 1024

# %% [markdown]
# show row index and coloum

# %%
df.shape
# Out:
# (128, 8)

# %% [markdown]
# rows and cloumn

# %%
df.memory_usage()
# Out:
# Index            132
# Home            1024
# Price           1024
# SqFt            1024
# Bedrooms        1024
# Bathrooms       1024
# Offers          1024
# Brick           1024
# Neighborhood    1024
# dtype: int64

# %%
 print(df.empty)
# Out:
# False

# %% [markdown]
#  checks wheather dataframe is empty or not
